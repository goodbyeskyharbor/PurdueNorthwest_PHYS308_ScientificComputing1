# %% [markdown]
# ### HW 3 - Computational Integrals and Derivatives

# %% [markdown]
# This problem contains four problems.
#
# 1. Newman "Computational Physics" problem 5.1
#
# 2. Newman "Computational Physics" problem 5.3
#
# 3. Newman "Computational Physics" problem 5.15
#
# 4. Newman "Computational Physics" problem 5.23

# %% [markdown]
# ### 1. Problem 5.1
#
# In class we learned how to calculate a integral for a given function. In this problem we don't know the functional form. Instead we have sampled points from a measurement of velocity as a function of time. Modify your trapezoid integral code to handle sampled data.

# %% [markdown]
# <img src="https://github.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/blob/master/Homework/Problem_Images/HW3_5p1a.jpg?raw=true">
# <img src="https://github.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/blob/master/Homework/Problem_Images/HW3_5p1b.jpg?raw=true">

# %%
import numpy as np
import matplotlib.pyplot as plt
time, velocity = np.loadtxt('http://www-personal.umich.edu/~mejn/cp/data/velocities.txt', unpack=True)

# %% [markdown]
# ### 2. Problem 5.3
#
# Here we can practice using any of our integral methods to complete an integral which is not solveable by hand!
#
# <img src="https://github.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/blob/master/Homework/Problem_Images/HW3_5p3a.jpg?raw=true">
# <img src="https://github.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/blob/master/Homework/Problem_Images/HW3_5p3b.jpg?raw=true">

# %% [markdown]
# ### 3. Problem 5.15
#
# Practice computational derivatives.
#
# <img src="https://github.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/blob/master/Homework/Problem_Images/HW3_5p15.jpg?raw=true">

# %% [markdown]
# ### 4. Problem 5.23

# %% [markdown]
# <img src="https://github.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/blob/master/Homework/Problem_Images/HW3_5p23a.jpg?raw=true">
#
# <img src="https://github.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/blob/master/Homework/Problem_Images/HW3_5p23b.jpg?raw=true">

# %% [markdown]
# Step 1: Read in the data and plot it using imshow (see matplotlib notebook or page 102 of textbook). Try using two different color maps (for example gray and magma). Also plot a colorbar.

# %%
import numpy as np
w = np.loadtxt('http://www-personal.umich.edu/~mejn/cp/data/altitude.txt',float)
 # stm.txt

# %% [markdown]
# w(x,y) is an array where each value is the altitude of the surface of the earth at a given location. The index of the array corresponds simply to a grid of points.

# %%
np.shape(w)
# Out:
# (512, 1024)

# %%
w
# Out:
# array([[-4116.06, -4114.78, -4113.87, ..., -4122.67, -4120.08, -4117.81],
#        [-3969.33, -3959.2 , -3949.72, ..., -4007.06, -3993.46, -3980.39],
#        [-2652.85, -2647.95, -2648.86, ..., -2720.04, -2691.39, -2666.93],
#        ...,
#        [ 2981.16,  2979.56,  2977.87, ...,  2986.03,  2984.54,  2982.82],
#        [ 2897.12,  2896.19,  2895.3 , ...,  2900.22,  2899.22,  2898.19],
#        [ 2785.31,  2785.22,  2785.14, ...,  2785.62,  2785.57,  2785.44]])

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,7))
plt.imshow(w, interpolation='none', origin='upper', cmap='magma') #, norm=LogNorm()
plt.colorbar()
plt.show()

plt.figure(figsize=(16,7))
plt.imshow(w, interpolation='none', origin='upper', cmap='gray') #, norm=LogNorm()
plt.colorbar()
plt.show()

# %% [markdown]
# Step 2: We would like to calculate the intensity of light falling on a given area of land when the sun is at a certain angle. Once we have calculated this, we can plot that intensity and the result will be a "Relief map" (the image will appear to be 3D).

# %% [markdown]
# <img src="https://github.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/blob/master/Homework/Problem_Images/HW3_5p23c_WWtopo_shading.jpg?raw=true">

# %% [markdown]
# To do this we will have to calculate the gradient (using computational derivatives) at each point in order to find the normal vector. We will use this information to calculate the intensity of light falling on that surface.

# %% [markdown]
# <img src="https://github.com/jdolen/PurdueNorthwest_PHYS308_ScientificComputing1/blob/master/Homework/Problem_Images/HW3_5p23d_gradient.png?raw=true">

# %% [markdown]
# You can work on parts (a) (b) and (c) of the problem below:

# %%
# Newman problem 5.23
# Image processing
#
#    Given light coming in at a given angle,
#    the inensity of light falling on a surface
#    will depend on the angle of the light with respect to the surface
#
#    Find the angle of each surface with respect to the horizontal
#    using the fact that the gradient vector is orthogonal to the surface
#    (this will require derivatives)
#
#    One can then calculate the intensity of light at each point
#    for a given incoming light direction based on the dot product
#    between the light and the normal vector

import numpy as np
import matplotlib.pyplot as plt

# Angle of the light from the east-west axis (a=(cos(phi), sin(phi),0))
phi = 3*np.pi/4

# Grid spacing (miles)
h = 30000.0

# Read in the data
w = np.loadtxt("http://www-personal.umich.edu/~mejn/cp/data/altitude.txt",float)  #stm.txt

# Find the number of elements of w (2d array) in x and y
print("Array dimensions:",w.shape)
xsize, ysize =  w.shape[0], w.shape[1]
print("xsize:",xsize)
print("ysize:",ysize)

# Create empty 2d arrays of the same size as the altitude data
dx = np.empty([xsize,ysize],float)
dy = np.empty([xsize,ysize],float)

# Calcuate the partial derivative dx and dy at every point using
#  the central difference method



# Calculate the intensity at every point using the formula



# Plot the intensity using imshow and a gray colormap
# Out:
# Array dimensions: (512, 1024)
# xsize: 512
# ysize: 1024
